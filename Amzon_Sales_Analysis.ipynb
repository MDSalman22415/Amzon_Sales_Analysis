# %%
import numpy as np
import pandas as pd
import seaborn as sns
import  matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = 'plotly_white'

# %%
df = pd.read_csv('amazon_sales_data 2025.csv')

# %%
df
# Out:
#     Order ID        Date        Product     Category  Price  Quantity  \
# 0    ORD0001  14-03-2025  Running Shoes     Footwear     60         3
# 1    ORD0002  20-03-2025     Headphones  Electronics    100         4
# 2    ORD0003  15-02-2025  Running Shoes     Footwear     60         2
# 3    ORD0004  19-02-2025  Running Shoes     Footwear     60         3
# 4    ORD0005  10-03-2025     Smartwatch  Electronics    150         3
# ..       ...         ...            ...          ...    ...       ...
# 245  ORD0246  17-03-2025        T-Shirt     Clothing     20         2
# 246  ORD0247  30-03-2025          Jeans     Clothing     40         1
# 247  ORD0248  05-03-2025        T-Shirt     Clothing     20         2
# 248  ORD0249  08-03-2025     Smartwatch  Electronics    150         3
# 249  ORD0250  19-02-2025     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Category', 'Price', 'Quantity',
#        'Total Sales', 'Customer Name', 'Customer Location', 'Payment Method',
#        'Status'],
#       dtype='object')

# %%
df.head()
# Out:
#   Order ID        Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-2025  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-2025     Headphones  Electronics    100         4
# 2  ORD0003  15-02-2025  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-2025  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-2025     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    object
#  2   Product            250 non-null    object
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.6+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\md salman\AppData\Local\Temp\ipykernel_4548\2394721818.py:1: UserWarning:
#
# Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    datetime64[ns]
#  2   Product            250 non-null    object
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 21.6+ KB

# %%
df.isnull().sum()
# Out:
# Order ID             0
# Date                 0
# Product              0
# Category             0
# Price                0
# Quantity             0
# Total Sales          0
# Customer Name        0
# Customer Location    0
# Payment Method       0
# Status               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %% [markdown]
# # Category by total seals

# %%
category_by_total_seals = df.groupby('Category')['Total Sales'].sum().reset_index()
category_by_total_seals
# Out:
#           Category  Total Sales
# 0            Books         1035
# 1         Clothing         3540
# 2      Electronics       129950
# 3         Footwear         4320
# 4  Home Appliances       105000

# %%
fig = px.bar(category_by_total_seals,
            x='Category',
            y='Total Sales',
            title='Category by Total Selas on amzon')
fig.show()

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
product_by_total_selas = df.groupby('Product')['Total Sales'].sum().reset_index()
product_by_total_selas
# Out:
#            Product  Total Sales
# 0             Book         1035
# 1       Headphones         7300
# 2            Jeans         2480
# 3           Laptop        58400
# 4     Refrigerator        78000
# 5    Running Shoes         4320
# 6       Smartphone        48500
# 7       Smartwatch        15750
# 8          T-Shirt         1060
# 9  Washing Machine        27000

# %%
fig =px.bar(product_by_total_selas,
           x='Product',
           y='Total Sales',
           title='Product by total Selas')
fig.show()

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %% [markdown]
# # Customer Location by Total  Sales

# %%
customer_location_by_total_sales = df.groupby('Customer Location')['Total Sales'].sum().reset_index()
customer_location_by_total_sales
# Out:
#   Customer Location  Total Sales
# 0            Boston        26170
# 1           Chicago        20810
# 2            Dallas        27145
# 3            Denver        29785
# 4           Houston        28390
# 5       Los Angeles        17820
# 6             Miami        31700
# 7          New York        18940
# 8     San Francisco        16195
# 9           Seattle        26890

# %%
fig = px.bar(customer_location_by_total_sales,
            x='Customer Location',
            y='Total Sales',
            title='Customer Location by Total Sales')
fig.show()

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending
#
#    Month
# 0      3
# 1      3
# 2      2
# 3      2
# 4      3

# %%
df['year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending
#
#    Month  year
# 0      3  2025
# 1      3  2025
# 2      2  2025
# 3      2  2025
# 4      3  2025

# %% [markdown]
# # Monthly sales analysis

# %%
monthly_sales_analysis = df.groupby('Month')['Total Sales'].sum().reset_index()
monthly_sales_analysis
# Out:
#    Month  Total Sales
# 0      2       122695
# 1      3       117730
# 2      4         3420

# %%
fig = px.line(monthly_sales_analysis,
             x='Month',
             y='Total Sales',
             title='Monthly sales analysis')
fig.show()
